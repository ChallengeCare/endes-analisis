# %% [markdown]
# # Historical DBF to CSV

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import os
import glob

# %%
# !pip install simpledbf
# Out:
# Collecting simpledbf
#   Downloading simpledbf-0.2.6.tar.gz (17 kB)
# Building wheels for collected packages: simpledbf
#   Building wheel for simpledbf (setup.py): started
#   Building wheel for simpledbf (setup.py): finished with status 'done'
#   Created wheel for simpledbf: filename=simpledbf-0.2.6-py3-none-any.whl size=13796 sha256=d6bbacdb600519f815a6ce36e89f78006b4fc7b651bcf0775df596a897ec07d9
#   Stored in directory: d:\users\dascencr\appdata\local\pip\cache\wheels\7c\4a\85\8d25e6dc4d2968a93a5459ed0153fd6f67041cfece137ca9ce
# Successfully built simpledbf
# Installing collected packages: simpledbf
# Successfully installed simpledbf-0.2.6

# %%
from simpledbf import Dbf5

# %% [markdown]
# ## Test

# %%
dbf = Dbf5('../files/00_raw_download/2019_ENDES/Modulo569_programas_sociales/PS_VL.dbf', codec='utf-8')

# %%
dbf.numrec
# Out:
# 9183

# %%
dbf.fields
# Out:
# [('DeletionFlag', 'C', 1),
#  ('ID1', 'N', 4),
#  ('HHID', 'C', 15),
#  ('HVIDX', 'N', 2),
#  ('QHCLUSTER', 'N', 4),
#  ('QHNUMBER', 'N', 3),
#  ('QHHOME', 'N', 2),
#  ('PS102_1A', 'N', 2),
#  ('PS102_1M', 'N', 2),
#  ('PS102_1S', 'N', 1),
#  ('PS4', 'N', 1)]

# %%
dbf.mem()
# Out:
# This total process would require more than 0.6481 MB of RAM.

# %%
dbf.to_csv('../files/07_tmp/drop.csv')

# %%
data = pd.io.stata.read_stata('../files/00_raw_download/2015_ENDES/Modulo66/rec0111.dta')

# %%
data.head()
# Out:
#                caseid  v001  v002  v003  v004  v006  v007  v008  v009    v010  \
# 0        000102701  1     1    27     1     1     6  2015  1386   7.0  1985.0
# 1        000104301  1     1    43     1     1     6  2015  1386   4.0  1974.0
# 2        000104801  2     1    48     2     1     6  2015  1386   1.0  1980.0
# 3        000104801  3     1    48     3     1     6  2015  1386  11.0  1999.0
# 4        000105001  3     1    50     3     1     6  2015  1386   8.0  1993.0
#
#    ...  v160  v161     v166 v167 v168  ml101     v190    v191      v005  \
# 0  ...   NaN   lpg  no salt  NaN  NaN    NaN  poorest -124225  157692.0
# 1  ...    no   lpg   30 ppm  NaN  NaN    NaN   poorer   15786  157692.0
# 2  ...    no   lpg    7 ppm  NaN  NaN    NaN   middle   31424  723389.0
# 3  ...    no   lpg    7 ppm  NaN  NaN    NaN   middle   31424  723389.0
# 4  ...    no   lpg   30 ppm  NaN  NaN    NaN   middle   45019  723389.0
#
#    hv005x
# 0  147527
# 1  147527
# 2  147527
# 3  147527
# 4  147527
#
# [5 rows x 96 columns]

# %%
data.to_csv('../files/07_tmp/drop_ga.csv',index=False)

# %% [markdown]
# ## Define functions

# %%
def dbf_to_csv(path_dbf, path_csv):
    dbf = Dbf5(path_dbf, codec='ISO-8859-1')
    dbf.to_csv(path_csv)

# %%
def dta_to_csv(path_dta, path_csv):
    data = pd.io.stata.read_stata(path_dta)
    data.to_csv(path_csv,index=False)

# %% [markdown]
# ## For everything

# %%
csv_path = '../files/00_raw_download/'

# %%
drop_path = '../files/01_csv/csv_by_year/'

# %%
filenames_mapped =[os.path.splitext(f)[0] for f in  os.listdir(csv_path)]
filenames_mapped
# Out:
# ['2009_ENDES',
#  '2010_ENDES',
#  '2011_ENDES',
#  '2012_ENDES',
#  '2013_ENDES',
#  '2014_ENDES',
#  '2015_ENDES',
#  '2016_ENDES',
#  '2017_ENDES',
#  '2018_ENDES',
#  '2019_ENDES']

# %%
for year in filenames_mapped:
    txt_guide = [f for f in glob.glob(f'{csv_path}{year}/*.txt')][0]
    txt_guide = txt_guide.split("\\")[-1]
    my_file = open(f'{csv_path}{year}/{txt_guide}', 'r')
    content_list = [f.strip().replace('\\','/').replace('\"','') for f in my_file.readlines()]
    print(f'Transforming {year}')
    for file_t in content_list:
        filename = file_t.split('/')[-1]
        path = '/'.join(file_t.split('/')[:-1])
        base, ext = filename.split('.')
        base = base.upper().replace(' ','_') 
        if not os.path.exists(f'{drop_path}{path}'): os.makedirs(f'{drop_path}{path}')
            
        if ext == 'dbf':
            dbf_to_csv(f'{csv_path}{file_t}', f'{drop_path}{path}/{base}.csv')
            print(f'{file_t} processed, DBF file')
        else:
            dta_to_csv(f'{csv_path}{file_t}', f'{drop_path}{path}/{base}.csv')
            print(f'{file_t} processed, DTA file')
# Out:
# Transforming 2009_ENDES
# 2009_ENDES/Modulo74/rec44.dbf processed, DBF file
# 2009_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# 2009_ENDES/Modulo73/rec83.dbf processed, DBF file
# 2009_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2009_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2009_ENDES/Modulo71/re516171.dbf processed, DBF file
# 2009_ENDES/Modulo70/rec95.dbf processed, DBF file
# 2009_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2009_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2009_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2009_ENDES/Modulo69/rec41.dbf processed, DBF file
# 2009_ENDES/Modulo67/rec21.dbf processed, DBF file
# 2009_ENDES/Modulo67/re223132.dbf processed, DBF file
# 2009_ENDES/Modulo66/REC0111.dbf processed, DBF file
# 2009_ENDES/Modulo66/REC91.dbf processed, DBF file
# 2009_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2009_ENDES/Modulo65/rech8.dbf processed, DBF file
# 2009_ENDES/Modulo64/rech8.dbf processed, DBF file
# 2009_ENDES/Modulo64/rech4.dbf processed, DBF file
# 2009_ENDES/Modulo64/rech1.dbf processed, DBF file
# 2009_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2009_ENDES/Modulo74/RECH6.dbf processed, DBF file
# 2009_ENDES/Modulo74/rech5.dbf processed, DBF file
# Transforming 2010_ENDES
# 2010_ENDES/Modulo74/RECH5.dbf processed, DBF file
# 2010_ENDES/Modulo64/RECH4.dbf processed, DBF file
# 2010_ENDES/Modulo64/RECH1.dbf processed, DBF file
# 2010_ENDES/Modulo64/RECH0.dbf processed, DBF file
# 2010_ENDES/Modulo71/REC516171.dbf processed, DBF file
# 2010_ENDES/Modulo66/REC0111.dbf processed, DBF file
# 2010_ENDES/Modulo70/REC95.dbf processed, DBF file
# 2010_ENDES/Modulo69/REC94.dbf processed, DBF file
# 2010_ENDES/Modulo66/REC91.dbf processed, DBF file
# 2010_ENDES/Modulo73/REC84DV.dbf processed, DBF file
# 2010_ENDES/Modulo73/REC83.dbf processed, DBF file
# 2010_ENDES/Modulo72/REC82.dbf processed, DBF file
# 2010_ENDES/Modulo74/REC44.dbf processed, DBF file
# 2010_ENDES/Modulo70/REC43.dbf processed, DBF file
# 2010_ENDES/Modulo70/REC42.dbf processed, DBF file
# 2010_ENDES/Modulo69/REC41.dbf processed, DBF file
# 2010_ENDES/Modulo67/REC21.dbf processed, DBF file
# 2010_ENDES/Modulo72/RE758081.dbf processed, DBF file
# 2010_ENDES/Modulo67/RE223132.dbf processed, DBF file
# 2010_ENDES/Modulo64/RECH9.dbf processed, DBF file
# 2010_ENDES/Modulo65/RECH23.dbf processed, DBF file
# 2010_ENDES/Modulo64/RECH11.dbf processed, DBF file
# 2010_ENDES/Modulo64/RECH10.dbf processed, DBF file
# 2010_ENDES/Modulo74/RECH6.dbf processed, DBF file
# Transforming 2011_ENDES
# 2011_ENDES/Modulo74/rech5.dbf processed, DBF file
# 2011_ENDES/Modulo74/rech6.dbf processed, DBF file
# 2011_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# 2011_ENDES/Modulo73/rec83.dbf processed, DBF file
# 2011_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2011_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2011_ENDES/Modulo71/RE516171.dbf processed, DBF file
# 2011_ENDES/Modulo70/rec95.dbf processed, DBF file
# 2011_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2011_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2011_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2011_ENDES/Modulo69/rec41.dbf processed, DBF file
# 2011_ENDES/Modulo67/re223132.dbf processed, DBF file
# 2011_ENDES/Modulo66/REC91.dbf processed, DBF file
# 2011_ENDES/Modulo66/rec0111.dbf processed, DBF file
# 2011_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2011_ENDES/Modulo64/rech9.dbf processed, DBF file
# 2011_ENDES/Modulo64/rech1.dbf processed, DBF file
# 2011_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2011_ENDES/Modulo64/rech10.dbf processed, DBF file
# 2011_ENDES/Modulo64/rech11.dbf processed, DBF file
# 2011_ENDES/Modulo64/REC10.dbf processed, DBF file
# 2011_ENDES/Modulo64/RECH8.dbf processed, DBF file
# 2011_ENDES/Modulo64/RECH4.dbf processed, DBF file
# 2011_ENDES/Modulo67/REC21.dbf processed, DBF file
# 2011_ENDES/Modulo74/rec44.dbf processed, DBF file
# Transforming 2012_ENDES
# 2012_ENDES/Modulo73/rec83.dbf processed, DBF file
# 2012_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2012_ENDES/Modulo74/rec44.dbf processed, DBF file
# 2012_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2012_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2012_ENDES/Modulo69/rec41.dbf processed, DBF file
# 2012_ENDES/Modulo67/rec21.dbf processed, DBF file
# 2012_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2012_ENDES/Modulo67/re223132.dbf processed, DBF file
# 2012_ENDES/Modulo71/RE516171.dbf processed, DBF file
# 2012_ENDES/Modulo66/REC91.dbf processed, DBF file
# 2012_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2012_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2012_ENDES/Modulo64/rech11.dbf processed, DBF file
# 2012_ENDES/Modulo64/rech10.dbf processed, DBF file
# 2012_ENDES/Modulo64/rech9.dbf processed, DBF file
# 2012_ENDES/Modulo64/rech8.dbf processed, DBF file
# 2012_ENDES/Modulo74/rech6.dbf processed, DBF file
# 2012_ENDES/Modulo74/rech5.dbf processed, DBF file
# 2012_ENDES/Modulo64/rech4.dbf processed, DBF file
# 2012_ENDES/Modulo64/rech1.dbf processed, DBF file
# 2012_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2012_ENDES/Modulo66/rec0111.dbf processed, DBF file
# 2012_ENDES/Modulo70/rec95.dbf processed, DBF file
# 2012_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# Transforming 2013_ENDES
# 2013_ENDES/Modulo74/rech5.dbf processed, DBF file
# 2013_ENDES/Modulo74/rech6.dbf processed, DBF file
# 2013_ENDES/Modulo64/rech9.dbf processed, DBF file
# 2013_ENDES/Modulo64/rech10.dbf processed, DBF file
# 2013_ENDES/Modulo64/rech11.dbf processed, DBF file
# 2013_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2013_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2013_ENDES/Modulo414/CSALUD01.dbf processed, DBF file
# 2013_ENDES/Modulo64/RECH8.dbf processed, DBF file
# 2013_ENDES/Modulo66/REC91.dbf processed, DBF file
# 2013_ENDES/Modulo413/rec93dv disciplina.dbf processed, DBF file
# 2013_ENDES/Modulo67/RE223132.dbf processed, DBF file
# 2013_ENDES/Modulo71/RE516171.dbf processed, DBF file
# 2013_ENDES/Modulo414/csalud08.dbf processed, DBF file
# 2013_ENDES/Modulo67/rec21.dbf processed, DBF file
# 2013_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2013_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2013_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# 2013_ENDES/Modulo73/rec83.dbf processed, DBF file
# 2013_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2013_ENDES/Modulo74/rec44.dbf processed, DBF file
# 2013_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2013_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2013_ENDES/Modulo69/rec41.dbf processed, DBF file
# 2013_ENDES/Modulo70/rec95.dbf processed, DBF file
# 2013_ENDES/Modulo66/rec0111.dbf processed, DBF file
# 2013_ENDES/Modulo64/rech1.dbf processed, DBF file
# 2013_ENDES/Modulo64/rech4.dbf processed, DBF file
# Transforming 2014_ENDES
# 2014_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2014_ENDES/Modulo66/rec0111.dbf processed, DBF file
# 2014_ENDES/Modulo70/rec95.dbf processed, DBF file
# 2014_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2014_ENDES/Modulo413/rec93dv disciplina.dbf processed, DBF file
# 2014_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# 2014_ENDES/Modulo73/rec83.dbf processed, DBF file
# 2014_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2014_ENDES/Modulo74/rec44.dbf processed, DBF file
# 2014_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2014_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2014_ENDES/Modulo69/rec41.dbf processed, DBF file
# 2014_ENDES/Modulo67/rec21.dbf processed, DBF file
# 2014_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2014_ENDES/Modulo67/re223132.dbf processed, DBF file
# 2014_ENDES/Modulo569/ps_wawawasi.dbf processed, DBF file
# 2014_ENDES/Modulo569/ps_vl.dbf processed, DBF file
# 2014_ENDES/Modulo569/ps_trabaja.dbf processed, DBF file
# 2014_ENDES/Modulo569/ps_qaliwarma.dbf processed, DBF file
# 2014_ENDES/Modulo569/ps_pension65.dbf processed, DBF file
# 2014_ENDES/Modulo569/ps_comedor.dbf processed, DBF file
# 2014_ENDES/Modulo569/ps_beca18.dbf processed, DBF file
# 2014_ENDES/Modulo569/programas sociales x hogar.dbf processed, DBF file
# 2014_ENDES/Modulo414/csalud01.dbf processed, DBF file
# 2014_ENDES/Modulo414/csalud08.dbf processed, DBF file
# 2014_ENDES/Modulo66/REC91.dbf processed, DBF file
# 2014_ENDES/Modulo71/RE516171.dbf processed, DBF file
# 2014_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2014_ENDES/Modulo74/rech6.dbf processed, DBF file
# 2014_ENDES/Modulo74/rech5.dbf processed, DBF file
# 2014_ENDES/Modulo64/rech4.dbf processed, DBF file
# 2014_ENDES/Modulo64/rech1.dbf processed, DBF file
# Transforming 2015_ENDES
# 2015_ENDES/Modulo71/re516171.dta processed, DTA file
# 2015_ENDES/Modulo70/rec95.dta processed, DTA file
# 2015_ENDES/Modulo70/rec43.dta processed, DTA file
# 2015_ENDES/Modulo70/rec42.dta processed, DTA file
# 2015_ENDES/Modulo69/rec94.dta processed, DTA file
# 2015_ENDES/Modulo69/rec41.dta processed, DTA file
# 2015_ENDES/Modulo67/rec21.dta processed, DTA file
# 2015_ENDES/Modulo67/re223132.dta processed, DTA file
# 2015_ENDES/Modulo66/rec0111.dta processed, DTA file
# 2015_ENDES/Modulo66/rec91.dta processed, DTA file
# 2015_ENDES/Modulo65/rech23.dta processed, DTA file
# 2015_ENDES/Modulo64/rech4.dta processed, DTA file
# 2015_ENDES/Modulo64/rech0.dta processed, DTA file
# 2015_ENDES/Modulo414/csalud01.dta processed, DTA file
# 2015_ENDES/Modulo64/rech1.dta processed, DTA file
# 2015_ENDES/Modulo569/ps_wawawasi.dta processed, DTA file
# 2015_ENDES/Modulo569/ps_qaliwarma.dta processed, DTA file
# 2015_ENDES/Modulo569/ps_pension65.dta processed, DTA file
# 2015_ENDES/Modulo569/ps_comedor.dta processed, DTA file
# 2015_ENDES/Modulo569/ps_beca18.dta processed, DTA file
# 2015_ENDES/Modulo569/programas_sociales_x_hogar.dta processed, DTA file
# 2015_ENDES/Modulo414/csalud08.dta processed, DTA file
# 2015_ENDES/Modulo413/rec93dv_disciplina.dta processed, DTA file
# 2015_ENDES/Modulo74/rech6.dta processed, DTA file
# 2015_ENDES/Modulo74/rech5.dta processed, DTA file
# 2015_ENDES/Modulo74/rec44.dta processed, DTA file
# 2015_ENDES/Modulo73/rec84dv.dta processed, DTA file
# 2015_ENDES/Modulo73/rec83.dta processed, DTA file
# 2015_ENDES/Modulo72/rec82.dta processed, DTA file
# 2015_ENDES/Modulo72/re758081.dta processed, DTA file
# Transforming 2016_ENDES
# 2016_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2016_ENDES/Modulo67/re223132.dbf processed, DBF file
# 2016_ENDES/Modulo569/programas sociales x hogar.dbf processed, DBF file
# 2016_ENDES/Modulo569/ps_beca18.dbf processed, DBF file
# 2016_ENDES/Modulo569/ps_comedor.dbf processed, DBF file
# 2016_ENDES/Modulo569/ps_pension65.dbf processed, DBF file
# 2016_ENDES/Modulo569/ps_qaliwarma.dbf processed, DBF file
# 2016_ENDES/Modulo569/ps_wawawasi.dbf processed, DBF file
# 2016_ENDES/Modulo74/rec44.dbf processed, DBF file
# 2016_ENDES/Modulo74/rech6.dbf processed, DBF file
# 2016_ENDES/Modulo66/rec0111.dbf processed, DBF file
# 2016_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2016_ENDES/Modulo70/rec95.dbf processed, DBF file
# 2016_ENDES/Modulo71/re516171.dbf processed, DBF file
# 2016_ENDES/Modulo414/csalud08.dbf processed, DBF file
# 2016_ENDES/Modulo66/rec91.dbf processed, DBF file
# 2016_ENDES/Modulo414/csalud01.dbf processed, DBF file
# 2016_ENDES/Modulo64/rech4.dbf processed, DBF file
# 2016_ENDES/Modulo74/rech5.dbf processed, DBF file
# 2016_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2016_ENDES/Modulo64/rech1.dbf processed, DBF file
# 2016_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2016_ENDES/Modulo73/rec83.dbf processed, DBF file
# 2016_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# 2016_ENDES/Modulo413/rec93dvdisciplina.dbf processed, DBF file
# 2016_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2016_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2016_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2016_ENDES/Modulo67/rec21.dbf processed, DBF file
# 2016_ENDES/Modulo69/rec41.dbf processed, DBF file
# Transforming 2017_ENDES
# 2017_ENDES/Modulo569/ps_qaliwarma.dbf processed, DBF file
# 2017_ENDES/Modulo569/ps_trabaja.dbf processed, DBF file
# 2017_ENDES/Modulo569/ps_pension65.dbf processed, DBF file
# 2017_ENDES/Modulo569/ps_comedor.dbf processed, DBF file
# 2017_ENDES/Modulo569/programas sociales x hogar.dbf processed, DBF file
# 2017_ENDES/Modulo569/ps_beca18.dbf processed, DBF file
# 2017_ENDES/Modulo414/csalud08.dbf processed, DBF file
# 2017_ENDES/Modulo414/csalud01.dbf processed, DBF file
# 2017_ENDES/Modulo74/rec44.dbf processed, DBF file
# 2017_ENDES/Modulo74/rech6.dbf processed, DBF file
# 2017_ENDES/Modulo66/rec0111.dbf processed, DBF file
# 2017_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2017_ENDES/Modulo74/rech5.dbf processed, DBF file
# 2017_ENDES/Modulo64/rech4.dbf processed, DBF file
# 2017_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2017_ENDES/Modulo64/rech1.dbf processed, DBF file
# 2017_ENDES/Modulo70/rec95.dbf processed, DBF file
# 2017_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2017_ENDES/Modulo413/rec93dv disciplina.dbf processed, DBF file
# 2017_ENDES/Modulo66/rec91.dbf processed, DBF file
# 2017_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# 2017_ENDES/Modulo73/rec83.dbf processed, DBF file
# 2017_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2017_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2017_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2017_ENDES/Modulo69/rec41.dbf processed, DBF file
# 2017_ENDES/Modulo67/rec21.dbf processed, DBF file
# 2017_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2017_ENDES/Modulo71/re516171.dbf processed, DBF file
# 2017_ENDES/Modulo67/re223132.dbf processed, DBF file
# 2017_ENDES/Modulo569/ps_vl.dbf processed, DBF file
# 2017_ENDES/Modulo569/ps_wawawasi.dbf processed, DBF file
# Transforming 2018_ENDES
# 2018_ENDES/Modulo72/rec82.dbf processed, DBF file
# 2018_ENDES/Modulo74/rec44.dbf processed, DBF file
# 2018_ENDES/Modulo70/rec43.dbf processed, DBF file
# 2018_ENDES/Modulo70/rec42.dbf processed, DBF file
# 2018_ENDES/Modulo69/rec41.dbf processed, DBF file
# 2018_ENDES/Modulo67/rec21.dbf processed, DBF file
# 2018_ENDES/Modulo72/re758081.dbf processed, DBF file
# 2018_ENDES/Modulo71/re516171.dbf processed, DBF file
# 2018_ENDES/Modulo67/re223132.dbf processed, DBF file
# 2018_ENDES/Modulo64/rech0.dbf processed, DBF file
# 2018_ENDES/Modulo64/rech1.dbf processed, DBF file
# 2018_ENDES/Modulo64/rech4.dbf processed, DBF file
# 2018_ENDES/Modulo569/programas_sociales_x_hogar.dbf processed, DBF file
# 2018_ENDES/Modulo64/rechm.dbf processed, DBF file
# 2018_ENDES/Modulo569/ps_beca18.dbf processed, DBF file
# 2018_ENDES/Modulo569/ps_comedor.dbf processed, DBF file
# 2018_ENDES/Modulo569/ps_pension65.dbf processed, DBF file
# 2018_ENDES/Modulo569/ps_qaliwarma.dbf processed, DBF file
# 2018_ENDES/Modulo569/ps_trabaja.dbf processed, DBF file
# 2018_ENDES/Modulo569/ps_vl.dbf processed, DBF file
# 2018_ENDES/Modulo569/ps_wawawasi.dbf processed, DBF file
# 2018_ENDES/Modulo70/REC95.dbf processed, DBF file
# 2018_ENDES/Modulo74/RECH6.dbf processed, DBF file
# 2018_ENDES/Modulo414/CSALUD08.dbf processed, DBF file
# 2018_ENDES/Modulo414/CSALUD01.dbf processed, DBF file
# 2018_ENDES/Modulo66/REC0111.dbf processed, DBF file
# 2018_ENDES/Modulo66/rech23.dbf processed, DBF file
# 2018_ENDES/Modulo70/dit.dbf processed, DBF file
# 2018_ENDES/Modulo66/rec91_2.dbf processed, DBF file
# 2018_ENDES/Modulo66/rec91.dbf processed, DBF file
# 2018_ENDES/Modulo65/rech23.dbf processed, DBF file
# 2018_ENDES/Modulo74/rech5.dbf processed, DBF file
# 2018_ENDES/Modulo69/rec94.dbf processed, DBF file
# 2018_ENDES/Modulo413/rec93dvdisciplina.dbf processed, DBF file
# 2018_ENDES/Modulo73/rec84dv.dbf processed, DBF file
# 2018_ENDES/Modulo73/rec83.dbf processed, DBF file
# Transforming 2019_ENDES
# 2019_ENDES/Modulo569_programas_sociales/PS_VL.dbf processed, DBF file
# 2019_ENDES/Modulo569_programas_sociales/PS_QALIWARMA.dbf processed, DBF file
# 2019_ENDES/Modulo569_programas_sociales/PS_TRABAJA.dbf processed, DBF file
# 2019_ENDES/Modulo569_programas_sociales/PS_COMEDOR.dbf processed, DBF file
# 2019_ENDES/Modulo569_programas_sociales/PS_PENSION65.dbf processed, DBF file
# 2019_ENDES/Modulo569_programas_sociales/PS_BECA18.dbf processed, DBF file
# 2019_ENDES/Modulo414_encuesta_de_salud/CSALUD08.dbf processed, DBF file
# 2019_ENDES/Modulo414_encuesta_de_salud/CSALUD01.dbf processed, DBF file
# 2019_ENDES/Modulo413_disciplina_infantil/REC93DVdisciplina.dbf processed, DBF file
# 2019_ENDES/Modulo64_caracteristicas_del_hogar/RECH4.dbf processed, DBF file
# 2019_ENDES/Modulo74_peso_y_talla_-_anemia/RECH6.dbf processed, DBF file
# 2019_ENDES/Modulo74_peso_y_talla_-_anemia/RECH5.dbf processed, DBF file
# 2019_ENDES/Modulo74_peso_y_talla_-_anemia/REC44.dbf processed, DBF file
# 2019_ENDES/Modulo73_mortalidad_materna_-_violencia_familiar/REC84DV.dbf processed, DBF file
# 2019_ENDES/Modulo73_mortalidad_materna_-_violencia_familiar/REC83.dbf processed, DBF file
# 2019_ENDES/Modulo72_conocimiento_de_sida_y_uso_del_condon/REC82.dbf processed, DBF file
# 2019_ENDES/Modulo72_conocimiento_de_sida_y_uso_del_condon/RE758081.dbf processed, DBF file
# 2019_ENDES/Modulo71_nupcialidad_fecundidad_conyugue_y_mujer/RE516171.dbf processed, DBF file
# 2019_ENDES/Modulo70_inmunizacion_y_salud/REC95.dbf processed, DBF file
# 2019_ENDES/Modulo70_inmunizacion_y_salud/REC43.dbf processed, DBF file
# 2019_ENDES/Modulo70_inmunizacion_y_salud/REC42.dbf processed, DBF file
# 2019_ENDES/Modulo70_inmunizacion_y_salud/DIT.dbf processed, DBF file
# 2019_ENDES/Modulo69_embarazo_parto_puerperio_y_lactancia/REC94.dbf processed, DBF file
# 2019_ENDES/Modulo69_embarazo_parto_puerperio_y_lactancia/REC41.dbf processed, DBF file
# 2019_ENDES/Modulo67_hitoria_de_nacimiento-tabla_de_conocimiento_de_metodo/REC21.dbf processed, DBF file
# 2019_ENDES/Modulo67_hitoria_de_nacimiento-tabla_de_conocimiento_de_metodo/RE223132.dbf processed, DBF file
# 2019_ENDES/Modulo66_datos_basicos_del_MEF/RECH23.dbf processed, DBF file
# 2019_ENDES/Modulo66_datos_basicos_del_MEF/REC91.dbf processed, DBF file
# 2019_ENDES/Modulo66_datos_basicos_del_MEF/REC0111.dbf processed, DBF file
# 2019_ENDES/Modulo65_caracteristicas_de_la_vivienda/RECH23.dbf processed, DBF file
# 2019_ENDES/Modulo64_caracteristicas_del_hogar/RECHM.dbf processed, DBF file
# 2019_ENDES/Modulo64_caracteristicas_del_hogar/RECH1.dbf processed, DBF file
# 2019_ENDES/Modulo64_caracteristicas_del_hogar/RECH0.dbf processed, DBF file
# 2019_ENDES/Modulo569_programas_sociales/Programas sociales x hogar.dbf processed, DBF file
# 2019_ENDES/Modulo569_programas_sociales/PS_WAWAWASI.dbf processed, DBF file
