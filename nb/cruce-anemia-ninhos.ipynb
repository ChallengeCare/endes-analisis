# %%
import pandas as pd
import numpy as np
import os

# %%
# Path for csv
csv_path = '../files/01_csv/csv_by_year'

# %%
cols_ = ['ID1','HHID','HC0','HC1','HC27','HC57']

# %%
# especifico x persona
df_anemia_19 = pd.read_csv(f'{csv_path}/2019_ENDES/Modulo74_peso_y_talla_-_anemia/RECH6.csv', encoding =  "ISO-8859-1")
print(df_anemia_19.shape)
df_anemia_19.head()
# Out:
# (22143, 41)
#     ID1    HHID  HC0  HC1  HC2   HC3   HC4  HC5    HC6   HC7  ...  HC60  HC61  \
# 0  2019  100201    4    8  107   727  6511   39  10143  9519  ...     2   3.0
# 1  2019  102801    4   52  182  1059  5504   13  10053  6540  ...     2   2.0
# 2  2019  102801    5   18   93   790  2351  -72   9726   892  ...     2   2.0
# 3  2019  104801    5   42  145   963  3002  -52   9792  3385  ...     2   1.0
# 4  2019  113601    3    8   85   685  4210  -20   9922  6407  ...     2   2.0
#
#    HC62   HC63  HC64  HC68  HC70  HC71  HC72  HC73
# 0   5.0  141.0     2   3.0    63   185   200   195
# 1   5.0   17.0     2   2.0     9    52    70    71
# 2   5.0   34.0     3   2.0   -69   -84   -70   -61
# 3   1.0   49.0     3   1.0   -77   -30    21    24
# 4   3.0   95.0     3   2.0   -10    55    86    81
#
# [5 rows x 41 columns]

# %%
df_anemia_19 = df_anemia_19[cols_]
df_anemia_19.head()
# Out:
#     ID1    HHID  HC0  HC1  HC27  HC57
# 0  2019  100201    4    8     1     4
# 1  2019  102801    4   52     1     4
# 2  2019  102801    5   18     2     4
# 3  2019  104801    5   42     2     4
# 4  2019  113601    3    8     2     2

# %%
### 2018
df_anemia_18 = pd.read_csv(f'{csv_path}/2018_ENDES/Modulo74/RECH6.csv', encoding =  "ISO-8859-1")
print(df_anemia_18.shape)
df_anemia_18.head()
# Out:
# (24288, 40)
#       HHID  HC0  HC1  HC2  HC3   HC4  HC5    HC6   HC7  HC8  ...  HC60  HC61  \
# 0   903801    5    3   63  625  4890   -3   9988  4689   -8  ...     2     2
# 1  1104101    3    3   63  612  4826   -4   9982  7002   52  ...     2     2
# 2  1405002    3    3   62  600  3293  -44   9809  5910   23  ...     2     2
# 3  2104801    5    2   70  603  7611   71  10298  9936  249  ...     2     1
# 4  2604801    6    3   81  640  5892   23  10095  9498  164  ...     2     2
#
#    HC62  HC63  HC64  HC68  HC70  HC71  HC72  HC73
# 0   5.0  67.0     3   2.0   -16   -58   -67   -67
# 1   2.0  45.0     3   2.0   -13     4    22    14
# 2   3.0   NaN     1   2.0   -73   -26    41    22
# 3   2.0  67.0     4   1.0    70   177   172   189
# 4   1.0  77.0     5   2.0    19   139   169   170
#
# [5 rows x 40 columns]

# %%
df_anemia_18['ID1'] = 2018
df_anemia_18 = df_anemia_18[cols_ ]
df_anemia_18.head()
# Out:
#     ID1     HHID  HC0  HC1  HC27  HC57
# 0  2018   903801    5    3     1     9
# 1  2018  1104101    3    3     2     9
# 2  2018  1405002    3    3     1     9
# 3  2018  2104801    5    2     2     9
# 4  2018  2604801    6    3     1     9

# %%
df_anemia_18.HC57.value_counts(dropna = False)
# Out:
# 4    14355
# 3     5199
# 2     2448
# 9     2250
# 1       36
# Name: HC57, dtype: int64

# %%
### 2017
df_anemia_17 = pd.read_csv(f'{csv_path}/2017_ENDES/Modulo74/RECH6.csv', encoding =  "ISO-8859-1")
print(df_anemia_17.shape)
df_anemia_17.head()
# Out:
# (22483, 42)
#      HHID  HC0  HC1  HC2   HC3   HC4  HC5   HC6   HC7  HC8  ...  HC60  HC61  \
# 0  101401    4   42  117   887    41 -264  8918   109 -229  ...   994   1.0
# 1  103201    3   48  144  1000  3214  -46  9815  1713  -95  ...     2   2.0
# 2  103601    3   37  122   901   679 -149  9399   521 -163  ...     2   2.0
# 3  104501    3    1   44   514   358 -180  9234  4676   -8  ...     2   1.0
# 4  105201    3   10   94   692  1580 -100  9614  6642   42  ...     2   1.0
#
#    HC62   HC63  HC64  HC68  HC70  HC71  HC72  HC73
# 0   2.0  999.0    99   1.0  -288  -226   -91   -46
# 1   5.0    NaN     1   2.0   -69   -84   -62   -64
# 2   3.0    NaN     1   2.0  -182  -146   -71   -44
# 3   3.0   15.0     6   1.0  -226   -69   198    81
# 4   6.0  156.0     2   1.0  -100    80   173   185
#
# [5 rows x 42 columns]

# %%
df_anemia_17['ID1'] = 2017
df_anemia_17 = df_anemia_17[cols_ ]
df_anemia_17.head()
# Out:
#     ID1    HHID  HC0  HC1  HC27  HC57
# 0  2017  101401    4   42     1     4
# 1  2017  103201    3   48     2     4
# 2  2017  103601    3   37     1     4
# 3  2017  104501    3    1     2     9
# 4  2017  105201    3   10     2     4

# %%
### 2016
df_anemia_16 = pd.read_csv(f'{csv_path}/2016_ENDES/Modulo74/RECH6.csv', encoding =  "ISO-8859-1")
print(df_anemia_16.shape)
df_anemia_16.head()
# Out:
# (22682, 42)
#      HHID  HC0  HC1  HC2  HC3     HC4    HC5      HC6     HC7    HC8  ...  \
# 0  100301    3   35  151  978  8162.0   90.0  10360.0  6311.0   33.0  ...
# 1  102801    4   54  163  981   305.0 -187.0   9219.0  2514.0  -67.0  ...
# 2  106101    4   35  145  930  3621.0  -35.0   9859.0  5049.0    1.0  ...
# 3  108301    5   48  155  974  1407.0 -108.0   9571.0  3863.0  -29.0  ...
# 4  109301    3   17   87  731    77.0 -242.0   9081.0   393.0 -176.0  ...
#
#    HC60  HC61  HC62   HC63  HC64  HC68  HC70  HC71  HC72  HC73
# 0     2   2.0   5.0    NaN     1   2.0    60    49    28    13
# 1     1   1.0   3.0  100.0     3   1.0  -191   -46   113   121
# 2     2   2.0   3.0    NaN     1   2.0   -69    17    80    88
# 3     2   1.0   6.0   79.0     3   1.0  -127   -28    72    73
# 4     2   2.0   5.0    NaN     1   2.0  -249  -127   -11    37
#
# [5 rows x 42 columns]

# %%
df_anemia_16['ID1'] = 2016
df_anemia_16 = df_anemia_16[cols_ ]
df_anemia_16.head()
# Out:
#     ID1    HHID  HC0  HC1  HC27  HC57
# 0  2016  100301    3   35     1     4
# 1  2016  102801    4   54     1     4
# 2  2016  106101    4   35     1     4
# 3  2016  108301    5   48     2     4
# 4  2016  109301    3   17     2     2

# %%
### 2015
df_anemia_15 = pd.read_csv(f'{csv_path}/2015_ENDES/Modulo74/RECH6.csv', encoding =  "ISO-8859-1")
print(df_anemia_15.shape)
df_anemia_15.head()
# Out:
# (25527, 42)
#      hhid  hc0  hc1    hc2    hc3     hc4     hc5      hc6     hc7    hc8  \
# 0  102701    4   42  145.0  928.0   972.0  -130.0   9484.0  3652.0  -34.0
# 1  104301    3   24  126.0  844.0  3493.0   -39.0   9856.0  5588.0   15.0
# 2  108901    4   48  152.0  991.0  3012.0   -52.0   9793.0  3489.0  -39.0
# 3  109001    2   42  149.0  939.0  1692.0   -96.0   9620.0  4769.0   -6.0
# 4  200601    4   12   92.0  738.0  5162.0     4.0  10015.0  4270.0  -18.0
#
#    ... hc60       hc61 hc62   hc63 hc64       hc68    hc70   hc71   hc72  \
# 0  ...    1  secondary  2.0   87.0  3.0  secondary  -151.0  -22.0   92.0
# 1  ...    1  secondary  3.0   96.0  2.0  secondary   -89.0   31.0  107.0
# 2  ...    2  secondary  3.0   47.0  2.0  secondary   -75.0  -35.0   17.0
# 3  ...    1    primary  6.0    NaN  1.0    primary  -119.0    1.0   99.0
# 4  ...    2    primary  4.0  128.0  3.0    primary    16.0   33.0   34.0
#
#     hc73
# 0  105.0
# 1  124.0
# 2   15.0
# 3  109.0
# 4   32.0
#
# ...

# %%
[x.upper() for x in df_anemia_15.columns ]
# Out:
# ['HHID',
#  'HC0',
#  'HC1',
#  'HC2',
#  'HC3',
#  'HC4',
#  'HC5',
#  'HC6',
#  'HC7',
#  'HC8',
#  'HC9',
#  'HC10',
#  'HC11',
#  'HC12',
#  'HC13',
#  'HC15',
#  'HC16',
#  'HC17',
#  'HC18',
#  'HC19',
#  'HC27',
#  'HC30',
#  'HC31',
#  'HC32',
#  'HC33',
#  'HC51',
#  'HC52',
#  'HC53',
#  'HC55',
#  'HC56',
#  'HC57',
#  'HC58',
#  'HC60',
#  'HC61',
#  'HC62',
#  'HC63',
#  'HC64',
#  'HC68',
#  'HC70',
#  'HC71',
#  'HC72',
#  'HC73']

# %%
df_anemia_15.columns = [x.upper() for x in df_anemia_15.columns ]

# %%
df_anemia_15['ID1'] = 2015
df_anemia_15 = df_anemia_15[cols_ ]
df_anemia_15.head()
# Out:
#     ID1    HHID  HC0  HC1    HC27        HC57
# 0  2015  102701    4   42  female  not anemic
# 1  2015  104301    3   24    male        mild
# 2  2015  108901    4   48  female  not anemic
# 3  2015  109001    2   42  female  not anemic
# 4  2015  200601    4   12  female        mild

# %%
df_anemia = pd.concat([df_anemia_15,df_anemia_16,df_anemia_17,df_anemia_18,df_anemia_19], axis=0)

# %%
print(df_anemia_15.HC57.value_counts(dropna=False))
print()
print(df_anemia_16.HC57.value_counts(dropna=False))
print()
print(df_anemia_17.HC57.value_counts(dropna=False))
print()
print(df_anemia_18.HC57.value_counts(dropna=False))
print()
print(df_anemia_19.HC57.value_counts(dropna=False))
print()
# Out:
# not anemic    14643
# mild           5300
# NaN            2959
# moderate       2551
# severe           74
# Name: HC57, dtype: int64
#
# 4    12902
# 3     4894
# 9     2521
# 2     2307
# 1       58
# Name: HC57, dtype: int64
#
# 4    12914
# 3     4941
# 2     2329
# 9     2246
# 1       53
# Name: HC57, dtype: int64
#
# 4    14355
# 3     5199
# 2     2448
# 9     2250
# 1       36
# Name: HC57, dtype: int64
#
# 4    13671
# 3     4516
# 9     2058
# 2     1876
# 1       22
# Name: HC57, dtype: int64

# %%
dict_anemia = {
    1: '1 - Severa',
    2: '2 - Moderada',
    3: '3 - Leve',
    4: '4 - Sin anemia',
    'severe': '1 - Severa',
    'moderate': '2 - Moderada',
    'mild': '3 - Leve',
    'not anemic': '4 - Sin anemia',
    9: np.nan  
    
}

# %%
df_anemia.HC57 = df_anemia.HC57.apply(lambda x: dict_anemia[x] if not pd.isna(x) else x)

# %%
df_anemia.HC57.value_counts(dropna = False)
# Out:
# 4 - Sin anemia    68485
# 3 - Leve          24850
# NaN               12034
# 2 - Moderada      11511
# 1 - Severa          243
# Name: HC57, dtype: int64

# %%
df_anemia = df_anemia[df_anemia['HC57'].notna()]

# %%
df_anemia.HC57.value_counts(dropna = False)
# Out:
# 4 - Sin anemia    68485
# 3 - Leve          24850
# 2 - Moderada      11511
# 1 - Severa          243
# Name: HC57, dtype: int64

# %%
df_base = pd.read_csv('../../pitch.csv')

# %%
df_base.columns
# Out:
# Index(['anho', 'casa_id', 'nro_vivientes_jure', 'nro_vivientes_facto',
#        'region', 'area_residencia', 'fuente_agua', 'tipo_banho', 'tipo_piso',
#        'indice_riqueza', 'persona_id', 'sexo', 'edad', 'educacion'],
#       dtype='object')

# %%
df_base = df_base[['anho', 'casa_id', 'nro_vivientes_jure', 'nro_vivientes_facto',
       'region', 'area_residencia', 'fuente_agua', 'tipo_banho', 'tipo_piso',
       'indice_riqueza']]

# %%
df_base.shape
# Out:
# (818979, 10)

# %%
df_base = df_base.drop_duplicates(keep='last')

# %%
df_base.shape
# Out:
# (197429, 10)

# %%
df_anemia.shape
# Out:
# (105089, 6)

# %%
df_anemia.columns
# Out:
# Index(['ID1', 'HHID', 'HC0', 'HC1', 'HC27', 'HC57'], dtype='object')

# %%
df_anemia.columns = ['anho', 'casa_id', 'ninho_casa_id', 'meses', 'sexo', 'flag_anemia']

# %%
df_anemia.sexo.value_counts(dropna = False)
# Out:
# 1         42290
# 2         40231
# male      11557
# female    11011
# Name: sexo, dtype: int64

# %%
df_anemia.meses.value_counts(dropna = False)
# Out:
# 50    2103
# 33    2072
# 32    2036
# 48    2035
# 41    2031
# 37    2023
# 46    2020
# 45    2012
# 44    2012
# 55    2009
# 27    2008
# 52    2007
# 38    2001
# 47    1994
# 53    1994
# 40    1990
# 58    1987
# 36    1983
# 20    1982
# 39    1978
# 54    1973
# 51    1973
# 35    1970
# 31    1969
# 43    1960
# 30    1955
# 15    1954
# 25    1950
# 49    1945
# 28    1938
# 29    1937
# 59    1934
# 18    1931
# 13    1925
# 34    1924
# 24    1920
# 23    1919
# 10    1911
# 22    1910
# 56    1909
# 14    1908
# 42    1903
# 19    1902
# 21    1897
# 26    1897
# 57    1896
# 9     1894
# 17    1893
# 12    1891
# 8     1872
# 11    1847
# 16    1830
# 7     1807
# 6     1561
# 5        6
# 3        1
# Name: meses, dtype: int64

# %%
dict_sexo = {
    1: 'Hombre',
    2: 'Mujer',
    'male': 'Hombre',
    'female': 'Mujer'
}

# %%
df_anemia.sexo = df_anemia.sexo.apply(lambda x: dict_sexo[x] if not pd.isna(x) else x)

# %%
df_anemia.sexo.value_counts(dropna = False)
# Out:
# Hombre    53847
# Mujer     51242
# Name: sexo, dtype: int64

# %%
df_anemia_complete = pd.merge(df_base, df_anemia, how='inner', on=['anho', 'casa_id'])

# %%
df_anemia_complete.shape
# Out:
# (102796, 14)

# %%
df_anemia_complete.sexo.value_counts()
# Out:
# Hombre    52702
# Mujer     50094
# Name: sexo, dtype: int64

# %%
df_anemia_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102796 entries, 0 to 102795
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   anho                 102796 non-null  int64
#  1   casa_id              102796 non-null  int64
#  2   nro_vivientes_jure   102796 non-null  int64
#  3   nro_vivientes_facto  102796 non-null  int64
#  4   region               102796 non-null  object
#  5   area_residencia      102796 non-null  object
#  6   fuente_agua          102796 non-null  object
#  7   tipo_banho           102796 non-null  object
#  8   tipo_piso            102796 non-null  object
#  9   indice_riqueza       102796 non-null  object
#  10  ninho_casa_id        102796 non-null  int64
#  11  meses                102796 non-null  int64
#  12  sexo                 102796 non-null  object
#  13  flag_anemia          102796 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 11.8+ MB

# %%
df_anemia_complete.to_csv('../files/01_csv/csv_consolidated/anemia_complete.csv',index=False)

# %%
import lightgbm as lgbm

# %%
cols_fit = ['nro_vivientes_jure', 'nro_vivientes_facto','region','area_residencia','fuente_agua',
                   'tipo_banho','tipo_piso','indice_riqueza',
                   'sexo','meses']
col_target = 'flag_anemia'

# %%
parameters = {
    'application': 'multiclass',
    'objective': 'softmax',
    'metric': 'multi_logloss',
    'is_unbalance': 'true',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'feature_fraction': 0.5,
    'bagging_fraction': 0.5,
    'bagging_freq': 20,
    'learning_rate': 0.05,
    'verbose': 0,
    'num_class': 4
}

# %%
from sklearn.model_selection import train_test_split

# %%
df_anemia_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102796 entries, 0 to 102795
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   anho                 102796 non-null  int64
#  1   casa_id              102796 non-null  int64
#  2   nro_vivientes_jure   102796 non-null  int64
#  3   nro_vivientes_facto  102796 non-null  int64
#  4   region               102796 non-null  object
#  5   area_residencia      102796 non-null  object
#  6   fuente_agua          102796 non-null  object
#  7   tipo_banho           102796 non-null  object
#  8   tipo_piso            102796 non-null  object
#  9   indice_riqueza       102796 non-null  object
#  10  ninho_casa_id        102796 non-null  int64
#  11  meses                102796 non-null  int64
#  12  sexo                 102796 non-null  object
#  13  flag_anemia          102796 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 11.8+ MB

# %%
df_anemia_complete.flag_anemia.value_counts(dropna=False)
# Out:
# 4 - Sin anemia    66928
# 3 - Leve          24369
# 2 - Moderada      11258
# 1 - Severa          241
# Name: flag_anemia, dtype: int64

# %%
df_anemia_complete.loc[:, df_anemia_complete.dtypes == 'object'] =\
    df_anemia_complete.select_dtypes(['object'])\
    .apply(lambda x: x.astype('category'))

# %%
df_anemia_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102796 entries, 0 to 102795
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   anho                 102796 non-null  int64
#  1   casa_id              102796 non-null  int64
#  2   nro_vivientes_jure   102796 non-null  int64
#  3   nro_vivientes_facto  102796 non-null  int64
#  4   region               102796 non-null  category
#  5   area_residencia      102796 non-null  category
#  6   fuente_agua          102796 non-null  category
#  7   tipo_banho           102796 non-null  category
#  8   tipo_piso            102796 non-null  category
#  9   indice_riqueza       102796 non-null  category
#  10  ninho_casa_id        102796 non-null  int64
#  11  meses                102796 non-null  int64
#  12  sexo                 102796 non-null  category
#  13  flag_anemia          102796 non-null  category
# dtypes: category(8), int64(6)
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
feature= df_anemia_complete[cols_fit]
target= le.fit_transform(df_anemia_complete[col_target])
feature_train, feature_test, target_train, target_test= train_test_split(feature, target, test_size=0.20)

# %%
train_data = lgbm.Dataset(feature_train, label=target_train)
test_data = lgbm.Dataset(feature_test, label=target_test)

# %%
model = lgbm.train(parameters,
                       train_data,
                       valid_sets=test_data,
                       num_boost_round=5000,
                       early_stopping_rounds=100)
# Out:
# [1]	valid_0's multi_logloss: 0.867241
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.861345
# [3]	valid_0's multi_logloss: 0.855952
# [4]	valid_0's multi_logloss: 0.852388
# [5]	valid_0's multi_logloss: 0.84928
# [6]	valid_0's multi_logloss: 0.845712
# [7]	valid_0's multi_logloss: 0.841217
# [8]	valid_0's multi_logloss: 0.839879
# [9]	valid_0's multi_logloss: 0.838574
# [10]	valid_0's multi_logloss: 0.836106
# [11]	valid_0's multi_logloss: 0.83232
# [12]	valid_0's multi_logloss: 0.830005
# [13]	valid_0's multi_logloss: 0.828746
# [14]	valid_0's multi_logloss: 0.826988
# [15]	valid_0's multi_logloss: 0.825175
# [16]	valid_0's multi_logloss: 0.823326
# [17]	valid_0's multi_logloss: 0.821313
# [18]	valid_0's multi_logloss: 0.8198
# [19]	valid_0's multi_logloss: 0.81836
# [20]	valid_0's multi_logloss: 0.816789
# [21]	valid_0's multi_logloss: 0.814557
# [22]	valid_0's multi_logloss: 0.813107
# [23]	valid_0's multi_logloss: 0.812547
# ...

# %%
ax = lgbm.plot_importance(model, max_num_features=40, figsize=(15,15))

# %%
ax.figure.savefig('../files/08_plots/feat_imp_anemia.png')
